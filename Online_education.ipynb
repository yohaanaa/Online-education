# %% [markdown]
# source data : https://www.kaggle.com/datasets/mdmahmudulhasansuzan/students-adaptability-level-in-online-education
#
# Acknowledgements
# You are free to use this dataset for any analysis or research purpose but please cite the original research paper. Students' Adaptability Level Prediction in Online Education using Machine Learning Approaches or DOI: 10.1109/ICCCNT51525.2021.9579741

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
student=pd.read_csv('students_adaptability_level_online_education.csv')
student.head()
# Out:
#   Gender    Age Education Level Institution Type IT Student Location  \
# 0    Boy  21-25      University   Non Government         No      Yes
# 1   Girl  21-25      University   Non Government         No      Yes
# 2   Girl  16-20         College       Government         No      Yes
# 3   Girl  11-15          School   Non Government         No      Yes
# 4   Girl  16-20          School   Non Government         No      Yes
#
#   Load-shedding Financial Condition Internet Type Network Type Class Duration  \
# 0           Low                 Mid          Wifi           4G            3-6
# 1          High                 Mid   Mobile Data           4G            1-3
# 2           Low                 Mid          Wifi           4G            1-3
# 3           Low                 Mid   Mobile Data           4G            1-3
# 4           Low                Poor   Mobile Data           3G              0
#
#   Self Lms  Device Adaptivity Level
# 0       No     Tab         Moderate
# ...

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               1205 non-null   object
#  1   Age                  1205 non-null   object
#  2   Education Level      1205 non-null   object
#  3   Institution Type     1205 non-null   object
#  4   IT Student           1205 non-null   object
#  5   Location             1205 non-null   object
#  6   Load-shedding        1205 non-null   object
#  7   Financial Condition  1205 non-null   object
#  8   Internet Type        1205 non-null   object
#  9   Network Type         1205 non-null   object
#  10  Class Duration       1205 non-null   object
#  11  Self Lms             1205 non-null   object
#  12  Device               1205 non-null   object
#  13  Adaptivity Level     1205 non-null   object
# dtypes: object(14)
# memory usage: 131.9+ KB

# %%
student.isna().sum()
# Out:
# Gender                 0
# Age                    0
# Education Level        0
# Institution Type       0
# IT Student             0
# Location               0
# Load-shedding          0
# Financial Condition    0
# Internet Type          0
# Network Type           0
# Class Duration         0
# Self Lms               0
# Device                 0
# Adaptivity Level       0
# dtype: int64

# %%
student.duplicated().sum()
# Out:
# 949

# %%
student['Age']=student['Age'].astype('str')

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               1205 non-null   object
#  1   Age                  1205 non-null   object
#  2   Education Level      1205 non-null   object
#  3   Institution Type     1205 non-null   object
#  4   IT Student           1205 non-null   object
#  5   Location             1205 non-null   object
#  6   Load-shedding        1205 non-null   object
#  7   Financial Condition  1205 non-null   object
#  8   Internet Type        1205 non-null   object
#  9   Network Type         1205 non-null   object
#  10  Class Duration       1205 non-null   object
#  11  Self Lms             1205 non-null   object
#  12  Device               1205 non-null   object
#  13  Adaptivity Level     1205 non-null   object
# dtypes: object(14)
# memory usage: 131.9+ KB

# %%
student['Adaptivity Level']
# Out:
# 0       Moderate
# 1       Moderate
# 2       Moderate
# 3       Moderate
# 4            Low
#           ...
# 1200         Low
# 1201    Moderate
# 1202    Moderate
# 1203         Low
# 1204    Moderate
# Name: Adaptivity Level, Length: 1205, dtype: object

# %%
student.groupby(['Education Level','Adaptivity Level'])['Age'].count().unstack()
# Out:
# Adaptivity Level  High  Low  Moderate
# Education Level
# College              3  120        96
# School              47  182       301
# University          50  178       228

# %%
df_gender=student[['Education Level','Financial Condition']].groupby(by='Financial Condition').count()
df_gender
# Out:
#                      Education Level
# Financial Condition
# Mid                              878
# Poor                             242
# Rich                              85

# %%
Salestype_count=df.groupby(['SaleType'],as_index=False).size()
Salestype_count

# %%
sns.countplot(data=student,
            x='Financial Condition',
            hue='Adaptivity Level')

# %%
From Adaptptivity level, people with condition moderate have highest adaptivity level online class.

# %%
sns.countplot(data=student,
            x='Education Level',
            hue='Adaptivity Level')

# %% [markdown]
# most of level scholol with moderate financial condition ghave highest adaptivity with online

# %%
sns.countplot(data=student,
            x='Education Level',
            hue='Financial Condition')

# %% [markdown]
# modearate financial condition have highest adaptivity in many eduactional level like university, college and school

# %%
Edu_Income=student.groupby(['Financial Condition'])['Adaptivity Level']
Edu_Income.describe()
# Out:
#                     count unique       top freq
# Financial Condition
# Mid                   878      3  Moderate  501
# Poor                  242      3       Low  129
# Rich                   85      3      High   42

# %%
Student.plot(kind='scatter', x='Gender', y='Adaptivity Level',alpha = 0.5,color = 'red')
plt.xlabel('Attack')              # label = name of label
plt.ylabel('Defence')
plt.title('Attack Defense Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Attack Defense Scatter Plot')

# %%
sns.lmplot(x="Financial Condition", y="Age", data=student)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-edd8c70e1fd1> in <module>()
# ----> 1 sns.lmplot(x="Financial Condition", y="Age", data=student)
#       2 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws, size)
# ...

# %%
f,ax = plt.subplots(figsize=(5, 5))
sns.heatmap(student.corr(), annot=True, linewidths=0.5,linecolor="red", fmt= '.1f',ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-349f154fbfad> in <module>()
#       1 f,ax = plt.subplots(figsize=(5, 5))
# ----> 2 sns.heatmap(student.corr(), annot=True, linewidths=0.5,linecolor="red", fmt= '.1f',ax=ax)
#       3 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...

# %%
print(student.corr())
# Out:
# Empty DataFrame
# Columns: []
# Index: []
